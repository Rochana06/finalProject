# %%
from huggingface_hub import login

# Replace 'your_hf_token' with your actual token from Hugging Face
login(token="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")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to C:\Users\rocha\.cache\huggingface\token
# Login successful

# %%
from huggingface_hub import whoami

user_info = whoami()
print(user_info)
# Out:
# {'type': 'user', 'id': '66e3f790d36ee014a48f7531', 'name': 'Rochana0608', 'fullname': 'Rochana Chandrashekara', 'email': 'rochana.c2000@gmail.com', 'emailVerified': True, 'canPay': False, 'periodEnd': None, 'isPro': False, 'avatarUrl': '/avatars/f7d53ed990ebadb80ac60346512b69da.svg', 'orgs': [], 'auth': {'type': 'access_token', 'accessToken': {'displayName': 'something', 'role': 'read', 'createdAt': '2024-09-16T16:13:09.045Z'}}}

# %%
from huggingface_hub import login

# Log in and add the token to git credentials
login(token="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", add_to_git_credential=True)
# Out:
# Token is valid (permission: read).
# Your token has been saved in your configured git credential helpers (manager).
# Your token has been saved to C:\Users\rocha\.cache\huggingface\token
# Login successful

# %%
# !pip install transformers datasets accelerate huggin
gface_hub

# %%
from datasets import load_dataset
from transformers import AutoTokenizer

# Load your dataset
import os

# Path to the extracted folder (update the path if necessary)
data_dir = r'C:\Users\rocha\OneDrive\Desktop\Dataset_1\Dataset\reentrancy (RE)'

# Dictionary to store smart contracts
contracts = {}

# Recursively traverse the directory to find .sol files
for root, dirs, files in os.walk(data_dir):
    print(f"Checking directory: {root}")  # Print the directory being checked
    for file in files:
        print(f"Found file: {file}")  # Print each file found
        if file.endswith('.sol'):
            file_path = os.path.join(root, file)
            print(f"Loading contract: {file_path}")  # Indicate that a .sol file is being loaded
            # Ignore invalid characters while reading
            with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
                contracts[file_path] = f.read()

# Print the number of contracts loaded
print(f"Loaded {len(contracts)} contracts.")

# %%
# Load a tokenizer that's compatible with Mistral 7B
tokenizer = AutoTokenizer.from_pretrained("mistralai/Mistral-7B")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~\huggingface_hub\src\huggingface_hub\utils\_errors.py:304, in hf_raise_for_status(response, endpoint_name)
#     303 try:
# --> 304     response.raise_for_status()
#     305 except HTTPError as e:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/mistralai/Mistral-7B/resolve/main/tokenizer_config.json
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# ...

# %%
def tokenize_function(examples):
    return tokenizer(examples["solidity_code"], truncation=True)

# Tokenize the dataset
tokenized_datasets = dataset.map(tokenize_function, batched=True)
# Out:
# Checking directory: C:\Users\rocha\OneDrive\Desktop\Dataset_1\Dataset\reentrancy (RE)
# Found file: 10.sol
# Loading contract: C:\Users\rocha\OneDrive\Desktop\Dataset_1\Dataset\reentrancy (RE)\10.sol
# Found file: 1002.sol
# Loading contract: C:\Users\rocha\OneDrive\Desktop\Dataset_1\Dataset\reentrancy (RE)\1002.sol
# Found file: 1009.sol
# Loading contract: C:\Users\rocha\OneDrive\Desktop\Dataset_1\Dataset\reentrancy (RE)\1009.sol
# Found file: 1011.sol
# Loading contract: C:\Users\rocha\OneDrive\Desktop\Dataset_1\Dataset\reentrancy (RE)\1011.sol
# Found file: 1021.sol
# Loading contract: C:\Users\rocha\OneDrive\Desktop\Dataset_1\Dataset\reentrancy (RE)\1021.sol
# Found file: 1023.sol
# Loading contract: C:\Users\rocha\OneDrive\Desktop\Dataset_1\Dataset\reentrancy (RE)\1023.sol
# Found file: 1030.sol
# Loading contract: C:\Users\rocha\OneDrive\Desktop\Dataset_1\Dataset\reentrancy (RE)\1030.sol
# Found file: 1055.sol
# ...

# %%
from transformers import AutoModelForCausalLM, Trainer, TrainingArguments

# Load Mistral 7B pre-trained model
model = AutoModelForCausalLM.from_pretrained("mistralai/Mistral-7B")

# Define training arguments
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=1,
    per_device_eval_batch_size=1,
    num_train_epochs=3,
    weight_decay=0.01,
    save_steps=10_000,
    save_total_limit=2,
    logging_dir="./logs",
)

# Initialize the Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
)

# Train the model
trainer.train()

# %%
pip install tf-keras

# %%
pip install keras==2.11

# %%
from transformers import AutoModelForCausalLM, Trainer, TrainingArguments

# Load Mistral 7B pre-trained model
model = AutoModelForCausalLM.from_pretrained("mistralai/Mistral-Small-Instruct-2409")

# Define training arguments
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=1,
    per_device_eval_batch_size=1,
    num_train_epochs=3,
    weight_decay=0.01,
    save_steps=10_000,
    save_total_limit=2,
    logging_dir="./logs",
)

# Initialize the Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
)

# Train the model
trainer.train()

# %%
# !where git
# Out:
# C:\Program Files\Git\cmd\git.exe

# %%
# !git status
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !mkdir finalProject

# %%
# %cd finalProject
# Out:
# C:\Users\rocha\finalProject
# C:\Users\rocha\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !dir
# Out:
#  Volume in drive C is Local Disk
#  Volume Serial Number is 62F3-888E
#
#  Directory of C:\Users\rocha\finalProject
#
# 25/09/2024  23:58    <DIR>          .
# 25/09/2024  23:58    <DIR>          ..
#                0 File(s)              0 bytes
#                2 Dir(s)  111,017,504,768 bytes free

# %%
# !git init
# Out:
# Initialized empty Git repository in C:/Users/rocha/finalProject/.git/
